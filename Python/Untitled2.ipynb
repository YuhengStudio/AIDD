# %%
# avogadro 常数
avogadro = 6.02e23 #等于6.02x10^23
print(avogadro)
# Out:
# 6.02e+23

# %%
# 纳摩尔浓度
concentration_nm = 5.5e-9   #等于5.5 x 10^-9
print(concentration_nm)     #5.5e-9
# Out:
# 5.5e-09

# %%
# IC50值
ic50 = 3.2e-8
print(ic50)
# Out:
# 3.2e-08

# %%
compound = {
    "name":"COF-5",
    "BET_surface_area":1670,
    "pore_size":2.7}
list(compound.keys())
# Out:
# ['name', 'BET_surface_area', 'pore_size']

# %%
1+1+2
# Out:
# 4

# %%
molecule_info = ("benzene", "C6H6", 78.11) 
molecule_info[0]
# Out:
# 'benzene'
